# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinate = list(lat_lngs)
len(coordinate)
# Out:
# 2000

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinate:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 300,
#    'main': 'Drizzle',
#    'description': 'light intensity drizzle',
#    'icon': '09n'},
#   {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}],
#  'base': 'stations',
#  'main': {'temp': 47.28,
#   'feels_like': 45.01,
#   'temp_min': 45.05,
#   'temp_max': 50.45,
#   'pressure': 1012,
#   'humidity': 90},
#  'visibility': 8047,
#  'wind': {'speed': 5.01, 'deg': 343, 'gust': 13},
#  'clouds': {'all': 90},
#  'dt': 1635391990,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1635333092,
#   'sunset': 1635371064},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
boston_data = city_weather.json()
boston_data["weather"][0]["description"]
# Out:
# 'light intensity drizzle'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pisco
# Processing Record 2 of Set 1 | westport
# Processing Record 3 of Set 1 | hithadhoo
# Processing Record 4 of Set 1 | rocha
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | ponta do sol
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | khandyga
# Processing Record 9 of Set 1 | kavieng
# Processing Record 10 of Set 1 | san vicente de canete
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | raga
# Processing Record 13 of Set 1 | clyde river
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 1 | winnemucca
# Processing Record 17 of Set 1 | lorengau
# Processing Record 18 of Set 1 | berbera
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | vila velha
# Processing Record 22 of Set 1 | salalah
# Processing Record 23 of Set 1 | marawi
# Processing Record 24 of Set 1 | iracoubo
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | vaasa
# Processing Record 29 of Set 1 | puerto ayora
# Processing Record 30 of Set 1 | victoria
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | salinopolis
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | broome
# Processing Record 36 of Set 1 | avera
# Processing Record 37 of Set 1 | buchanan
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | bharatpur
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | fare
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | mapiripan
# Processing Record 46 of Set 1 | tapaua
# City not found. Skipping...
# Processing Record 47 of Set 1 | srednekolymsk
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | kochevo
# Processing Record 3 of Set 2 | chokurdakh
# Processing Record 4 of Set 2 | kaitangata
# Processing Record 5 of Set 2 | flinders
# Processing Record 6 of Set 2 | nechi
# Processing Record 7 of Set 2 | katsuura
# Processing Record 8 of Set 2 | lebu
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 2 | hadejia
# Processing Record 14 of Set 2 | saint-pierre
# Processing Record 15 of Set 2 | alofi
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | yelizovo
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | cayenne
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | fereydun kenar
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | sao joao da barra
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | asau
# Processing Record 30 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 2 | ambunti
# Processing Record 32 of Set 2 | acarau
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | yulara
# Processing Record 35 of Set 2 | prince rupert
# Processing Record 36 of Set 2 | champerico
# Processing Record 37 of Set 2 | hervey bay
# Processing Record 38 of Set 2 | oshawa
# Processing Record 39 of Set 2 | isangel
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | independencia
# Processing Record 42 of Set 2 | coihaique
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | egvekinot
# Processing Record 45 of Set 2 | kieta
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | yar-sale
# Processing Record 48 of Set 2 | moerai
# Processing Record 49 of Set 2 | provideniya
# Processing Record 50 of Set 2 | iseyin
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | magole
# Processing Record 3 of Set 3 | tiksi
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | micheweni
# Processing Record 6 of Set 3 | rio verde de mato grosso
# Processing Record 7 of Set 3 | talnakh
# Processing Record 8 of Set 3 | waingapu
# Processing Record 9 of Set 3 | karratha
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | hobart
# Processing Record 12 of Set 3 | alihe
# Processing Record 13 of Set 3 | tuatapere
# Processing Record 14 of Set 3 | aginskoye
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | masaurhi
# Processing Record 17 of Set 3 | hanmer springs
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | kruisfontein
# Processing Record 20 of Set 3 | ilulissat
# Processing Record 21 of Set 3 | okha
# Processing Record 22 of Set 3 | shelburne
# Processing Record 23 of Set 3 | kapaa
# Processing Record 24 of Set 3 | dingle
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | esperance
# Processing Record 27 of Set 3 | seoul
# Processing Record 28 of Set 3 | gizo
# Processing Record 29 of Set 3 | sabha
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | pyinmana
# Processing Record 33 of Set 3 | kuusamo
# Processing Record 34 of Set 3 | roma
# Processing Record 35 of Set 3 | partapur
# Processing Record 36 of Set 3 | riyadh
# Processing Record 37 of Set 3 | andenes
# Processing Record 38 of Set 3 | tilichiki
# Processing Record 39 of Set 3 | dauphin
# Processing Record 40 of Set 3 | luanda
# Processing Record 41 of Set 3 | bilibino
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 3 | bubaque
# Processing Record 45 of Set 3 | daru
# Processing Record 46 of Set 3 | manbij
# Processing Record 47 of Set 3 | terdal
# Processing Record 48 of Set 3 | pemangkat
# Processing Record 49 of Set 3 | bambous virieux
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | vestmannaeyjar
# Processing Record 2 of Set 4 | ayr
# Processing Record 3 of Set 4 | nioro
# Processing Record 4 of Set 4 | san luis
# Processing Record 5 of Set 4 | syracuse
# Processing Record 6 of Set 4 | san clemente
# Processing Record 7 of Set 4 | olafsvik
# Processing Record 8 of Set 4 | mana
# Processing Record 9 of Set 4 | airai
# Processing Record 10 of Set 4 | kaduqli
# Processing Record 11 of Set 4 | san cristobal
# Processing Record 12 of Set 4 | namatanai
# Processing Record 13 of Set 4 | goiania
# Processing Record 14 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 4 | sorong
# Processing Record 16 of Set 4 | aksarka
# Processing Record 17 of Set 4 | barrow
# Processing Record 18 of Set 4 | sept-iles
# Processing Record 19 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 4 | haines junction
# Processing Record 21 of Set 4 | bethel
# Processing Record 22 of Set 4 | nyrob
# Processing Record 23 of Set 4 | marsabit
# Processing Record 24 of Set 4 | minab
# Processing Record 25 of Set 4 | samarai
# Processing Record 26 of Set 4 | mbacke
# City not found. Skipping...
# Processing Record 27 of Set 4 | nhulunbuy
# Processing Record 28 of Set 4 | reconquista
# Processing Record 29 of Set 4 | vila franca do campo
# Processing Record 30 of Set 4 | omachi
# Processing Record 31 of Set 4 | boysun
# Processing Record 32 of Set 4 | sitka
# Processing Record 33 of Set 4 | safaga
# Processing Record 34 of Set 4 | paamiut
# Processing Record 35 of Set 4 | ouadda
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | vardo
# Processing Record 38 of Set 4 | akyab
# Processing Record 39 of Set 4 | hofn
# Processing Record 40 of Set 4 | saint-georges
# Processing Record 41 of Set 4 | geraldton
# Processing Record 42 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 43 of Set 4 | leningradskiy
# Processing Record 44 of Set 4 | isla mujeres
# Processing Record 45 of Set 4 | helong
# Processing Record 46 of Set 4 | labuhan
# Processing Record 47 of Set 4 | baikunthpur
# Processing Record 48 of Set 4 | honiara
# Processing Record 49 of Set 4 | marzuq
# Processing Record 50 of Set 4 | lavrentiya
# Processing Record 1 of Set 5 | popondetta
# Processing Record 2 of Set 5 | grindavik
# Processing Record 3 of Set 5 | beloha
# Processing Record 4 of Set 5 | port elizabeth
# Processing Record 5 of Set 5 | harper
# Processing Record 6 of Set 5 | guasdualito
# Processing Record 7 of Set 5 | astoria
# Processing Record 8 of Set 5 | beachwood
# Processing Record 9 of Set 5 | hollins
# Processing Record 10 of Set 5 | nador
# Processing Record 11 of Set 5 | port lincoln
# Processing Record 12 of Set 5 | roald
# Processing Record 13 of Set 5 | alamos
# Processing Record 14 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 15 of Set 5 | pangkalanbuun
# Processing Record 16 of Set 5 | ukiah
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | anadyr
# Processing Record 19 of Set 5 | la cruz
# Processing Record 20 of Set 5 | wuwei
# Processing Record 21 of Set 5 | kuching
# Processing Record 22 of Set 5 | zaraza
# Processing Record 23 of Set 5 | licheng
# Processing Record 24 of Set 5 | atuona
# Processing Record 25 of Set 5 | sao filipe
# Processing Record 26 of Set 5 | unye
# City not found. Skipping...
# Processing Record 27 of Set 5 | mount isa
# Processing Record 28 of Set 5 | husavik
# Processing Record 29 of Set 5 | caraguatatuba
# Processing Record 30 of Set 5 | ramgarh
# Processing Record 31 of Set 5 | itaituba
# Processing Record 32 of Set 5 | cabo san lucas
# Processing Record 33 of Set 5 | faanui
# Processing Record 34 of Set 5 | kodiak
# Processing Record 35 of Set 5 | mindelo
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | lompoc
# Processing Record 38 of Set 5 | thinadhoo
# Processing Record 39 of Set 5 | saint-francois
# Processing Record 40 of Set 5 | bengkulu
# Processing Record 41 of Set 5 | gurgan
# City not found. Skipping...
# Processing Record 42 of Set 5 | milkovo
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 5 | maragogi
# Processing Record 46 of Set 5 | tezu
# Processing Record 47 of Set 5 | canico
# Processing Record 48 of Set 5 | makurdi
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 50 of Set 5 | hambantota
# Processing Record 1 of Set 6 | saint-augustin
# Processing Record 2 of Set 6 | xuddur
# Processing Record 3 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 6 | nizhniy tsasuchey
# Processing Record 5 of Set 6 | touros
# Processing Record 6 of Set 6 | toora-khem
# Processing Record 7 of Set 6 | shubarshi
# Processing Record 8 of Set 6 | great falls
# Processing Record 9 of Set 6 | itarema
# Processing Record 10 of Set 6 | changli
# Processing Record 11 of Set 6 | unai
# Processing Record 12 of Set 6 | cockburn town
# Processing Record 13 of Set 6 | laguna
# Processing Record 14 of Set 6 | lewiston
# Processing Record 15 of Set 6 | elmira
# Processing Record 16 of Set 6 | kentau
# Processing Record 17 of Set 6 | sola
# Processing Record 18 of Set 6 | amlimay
# Processing Record 19 of Set 6 | mitsamiouli
# Processing Record 20 of Set 6 | espinosa
# Processing Record 21 of Set 6 | qinhuangdao
# Processing Record 22 of Set 6 | melilla
# Processing Record 23 of Set 6 | zhuhai
# Processing Record 24 of Set 6 | juneau
# Processing Record 25 of Set 6 | fort morgan
# Processing Record 26 of Set 6 | bambanglipuro
# Processing Record 27 of Set 6 | san pedro
# Processing Record 28 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 6 | auki
# Processing Record 30 of Set 6 | zyryanka
# Processing Record 31 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 6 | ketchikan
# Processing Record 33 of Set 6 | maniitsoq
# Processing Record 34 of Set 6 | henties bay
# Processing Record 35 of Set 6 | sisimiut
# Processing Record 36 of Set 6 | banda aceh
# Processing Record 37 of Set 6 | wamba
# Processing Record 38 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 39 of Set 6 | visnes
# Processing Record 40 of Set 6 | narsaq
# Processing Record 41 of Set 6 | santo antonio do amparo
# Processing Record 42 of Set 6 | edgewater
# Processing Record 43 of Set 6 | puquio
# Processing Record 44 of Set 6 | atlanta
# Processing Record 45 of Set 6 | charters towers
# Processing Record 46 of Set 6 | quelimane
# Processing Record 47 of Set 6 | chupaca
# Processing Record 48 of Set 6 | ternate
# Processing Record 49 of Set 6 | russell
# Processing Record 50 of Set 6 | kabompo
# Processing Record 1 of Set 7 | butaritari
# Processing Record 2 of Set 7 | axim
# Processing Record 3 of Set 7 | kutum
# Processing Record 4 of Set 7 | hobyo
# Processing Record 5 of Set 7 | tommot
# Processing Record 6 of Set 7 | byron bay
# Processing Record 7 of Set 7 | tecoanapa
# Processing Record 8 of Set 7 | cambridge
# Processing Record 9 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 7 | balabac
# Processing Record 11 of Set 7 | sikasso
# Processing Record 12 of Set 7 | fortuna
# Processing Record 13 of Set 7 | boundiali
# Processing Record 14 of Set 7 | porto torres
# Processing Record 15 of Set 7 | le port
# Processing Record 16 of Set 7 | oussouye
# Processing Record 17 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 7 | vedasandur
# Processing Record 19 of Set 7 | shemordan
# Processing Record 20 of Set 7 | porto santo
# Processing Record 21 of Set 7 | naryan-mar
# Processing Record 22 of Set 7 | monrovia
# Processing Record 23 of Set 7 | zabolotovka
# Processing Record 24 of Set 7 | mahebourg
# Processing Record 25 of Set 7 | victor harbor
# Processing Record 26 of Set 7 | pionerskiy
# Processing Record 27 of Set 7 | lagoa
# Processing Record 28 of Set 7 | mogzon
# Processing Record 29 of Set 7 | ahipara
# Processing Record 30 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 7 | namtsy
# Processing Record 33 of Set 7 | tateyama
# Processing Record 34 of Set 7 | miri
# Processing Record 35 of Set 7 | evensk
# Processing Record 36 of Set 7 | villa bruzual
# Processing Record 37 of Set 7 | hirara
# Processing Record 38 of Set 7 | bonga
# Processing Record 39 of Set 7 | brae
# Processing Record 40 of Set 7 | mackay
# Processing Record 41 of Set 7 | pacific grove
# Processing Record 42 of Set 7 | ancud
# Processing Record 43 of Set 7 | alta floresta
# Processing Record 44 of Set 7 | kodinsk
# Processing Record 45 of Set 7 | south saint paul
# Processing Record 46 of Set 7 | susanville
# Processing Record 47 of Set 7 | darab
# Processing Record 48 of Set 7 | krasnoselkup
# Processing Record 49 of Set 7 | tiarei
# Processing Record 50 of Set 7 | lata
# Processing Record 1 of Set 8 | laibin
# Processing Record 2 of Set 8 | ulladulla
# Processing Record 3 of Set 8 | rivadavia
# Processing Record 4 of Set 8 | ca mau
# Processing Record 5 of Set 8 | bria
# Processing Record 6 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 8 | muros
# Processing Record 8 of Set 8 | ha noi
# Processing Record 9 of Set 8 | plettenberg bay
# Processing Record 10 of Set 8 | galesong
# Processing Record 11 of Set 8 | skagen
# Processing Record 12 of Set 8 | tevriz
# Processing Record 13 of Set 8 | mehamn
# Processing Record 14 of Set 8 | nampula
# Processing Record 15 of Set 8 | galle
# Processing Record 16 of Set 8 | bardiyah
# Processing Record 17 of Set 8 | kargil
# Processing Record 18 of Set 8 | college
# Processing Record 19 of Set 8 | taywarah
# Processing Record 20 of Set 8 | kemijarvi
# Processing Record 21 of Set 8 | calvinia
# Processing Record 22 of Set 8 | toamasina
# Processing Record 23 of Set 8 | faya
# Processing Record 24 of Set 8 | dicabisagan
# Processing Record 25 of Set 8 | lasa
# Processing Record 26 of Set 8 | erdenet
# Processing Record 27 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 8 | klaksvik
# Processing Record 29 of Set 8 | allapalli
# Processing Record 30 of Set 8 | pennadam
# Processing Record 31 of Set 8 | lyubar
# Processing Record 32 of Set 8 | wabash
# Processing Record 33 of Set 8 | limon
# Processing Record 34 of Set 8 | san quintin
# Processing Record 35 of Set 8 | miquelon
# Processing Record 36 of Set 8 | elmvale
# Processing Record 37 of Set 8 | maun
# Processing Record 38 of Set 8 | port hardy
# Processing Record 39 of Set 8 | milagres
# Processing Record 40 of Set 8 | kamenka
# Processing Record 41 of Set 8 | pantai remis
# Processing Record 42 of Set 8 | praia
# Processing Record 43 of Set 8 | bakchar
# Processing Record 44 of Set 8 | tazovskiy
# Processing Record 45 of Set 8 | stuttgart
# Processing Record 46 of Set 8 | villa maria
# Processing Record 47 of Set 8 | sevierville
# Processing Record 48 of Set 8 | hoi an
# Processing Record 49 of Set 8 | asbestos
# Processing Record 50 of Set 8 | sakakah
# Processing Record 1 of Set 9 | ust-kut
# Processing Record 2 of Set 9 | sal rei
# Processing Record 3 of Set 9 | kerema
# Processing Record 4 of Set 9 | pevek
# Processing Record 5 of Set 9 | nizhniy chir
# Processing Record 6 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 9 | northam
# Processing Record 9 of Set 9 | luena
# Processing Record 10 of Set 9 | ampanihy
# Processing Record 11 of Set 9 | nacala
# Processing Record 12 of Set 9 | wanning
# Processing Record 13 of Set 9 | fecamp
# Processing Record 14 of Set 9 | izumo
# Processing Record 15 of Set 9 | tromso
# Processing Record 16 of Set 9 | dasoguz
# Processing Record 17 of Set 9 | navolato
# Processing Record 18 of Set 9 | sokoni
# Processing Record 19 of Set 9 | nanchang
# Processing Record 20 of Set 9 | birao
# Processing Record 21 of Set 9 | sao geraldo do araguaia
# Processing Record 22 of Set 9 | pelym
# Processing Record 23 of Set 9 | constitucion
# Processing Record 24 of Set 9 | beaverlodge
# Processing Record 25 of Set 9 | naze
# Processing Record 26 of Set 9 | khash
# Processing Record 27 of Set 9 | san patricio
# Processing Record 28 of Set 9 | rabo de peixe
# Processing Record 29 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 9 | moron
# Processing Record 31 of Set 9 | bourail
# Processing Record 32 of Set 9 | santiago de cuba
# Processing Record 33 of Set 9 | wau
# Processing Record 34 of Set 9 | aksu
# Processing Record 35 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 9 | caibarien
# Processing Record 37 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 9 | skelleftea
# Processing Record 39 of Set 9 | tungor
# Processing Record 40 of Set 9 | kavaratti
# Processing Record 41 of Set 9 | pathein
# Processing Record 42 of Set 9 | palm valley
# Processing Record 43 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 9 | kibakwe
# Processing Record 45 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 9 | monterey
# Processing Record 48 of Set 9 | la rioja
# Processing Record 49 of Set 9 | mandera
# Processing Record 50 of Set 9 | ostersund
# Processing Record 1 of Set 10 | osorio
# Processing Record 2 of Set 10 | tukrah
# Processing Record 3 of Set 10 | tomatlan
# Processing Record 4 of Set 10 | tupik
# Processing Record 5 of Set 10 | flin flon
# Processing Record 6 of Set 10 | matagami
# Processing Record 7 of Set 10 | qui nhon
# Processing Record 8 of Set 10 | develi
# Processing Record 9 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 10 | gloversville
# Processing Record 11 of Set 10 | druzhba
# Processing Record 12 of Set 10 | vao
# Processing Record 13 of Set 10 | sangar
# Processing Record 14 of Set 10 | oistins
# Processing Record 15 of Set 10 | myaundzha
# Processing Record 16 of Set 10 | vicuna
# Processing Record 17 of Set 10 | lyaskelya
# Processing Record 18 of Set 10 | aswan
# Processing Record 19 of Set 10 | tanout
# Processing Record 20 of Set 10 | ellensburg
# Processing Record 21 of Set 10 | copiapo
# Processing Record 22 of Set 10 | arica
# Processing Record 23 of Set 10 | saravan
# Processing Record 24 of Set 10 | luderitz
# Processing Record 25 of Set 10 | kapoeta
# Processing Record 26 of Set 10 | mariental
# Processing Record 27 of Set 10 | samur
# Processing Record 28 of Set 10 | tjaereborg
# Processing Record 29 of Set 10 | ortona
# Processing Record 30 of Set 10 | fort nelson
# Processing Record 31 of Set 10 | sur
# Processing Record 32 of Set 10 | shahr-e babak
# Processing Record 33 of Set 10 | kupang
# Processing Record 34 of Set 10 | halifax
# Processing Record 35 of Set 10 | alice springs
# Processing Record 36 of Set 10 | stornoway
# Processing Record 37 of Set 10 | anaconda
# Processing Record 38 of Set 10 | besikduzu
# Processing Record 39 of Set 10 | hanzhong
# Processing Record 40 of Set 10 | sioux lookout
# Processing Record 41 of Set 10 | alvdal
# Processing Record 42 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 10 | adre
# Processing Record 44 of Set 10 | chapais
# Processing Record 45 of Set 10 | merauke
# Processing Record 46 of Set 10 | beringovskiy
# Processing Record 47 of Set 10 | omboue
# Processing Record 48 of Set 10 | mandalgovi
# Processing Record 49 of Set 10 | key west
# Processing Record 50 of Set 10 | kuito
# Processing Record 1 of Set 11 | north bend
# Processing Record 2 of Set 11 | hovd
# Processing Record 3 of Set 11 | marsh harbour
# Processing Record 4 of Set 11 | kazachinskoye
# Processing Record 5 of Set 11 | oskarshamn
# Processing Record 6 of Set 11 | pochutla
# Processing Record 7 of Set 11 | luunja
# Processing Record 8 of Set 11 | muana
# Processing Record 9 of Set 11 | ust-nera
# Processing Record 10 of Set 11 | launceston
# Processing Record 11 of Set 11 | hami
# Processing Record 12 of Set 11 | talcahuano
# Processing Record 13 of Set 11 | broken hill
# Processing Record 14 of Set 11 | soyo
# Processing Record 15 of Set 11 | dillon
# Processing Record 16 of Set 11 | manthani
# Processing Record 17 of Set 11 | prince albert
# Processing Record 18 of Set 11 | coahuayana
# Processing Record 19 of Set 11 | havoysund
# Processing Record 20 of Set 11 | ambovombe
# Processing Record 21 of Set 11 | porto walter
# Processing Record 22 of Set 11 | ayagoz
# Processing Record 23 of Set 11 | korla
# Processing Record 24 of Set 11 | fairbanks
# Processing Record 25 of Set 11 | masallatah
# Processing Record 26 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 11 | ust-koksa
# Processing Record 28 of Set 11 | matara
# Processing Record 29 of Set 11 | sinnamary
# Processing Record 30 of Set 11 | mogwase
# Processing Record 31 of Set 11 | obzor
# Processing Record 32 of Set 11 | camargo
# Processing Record 33 of Set 11 | nemuro
# Processing Record 34 of Set 11 | kununurra
# Processing Record 35 of Set 11 | pakokku
# Processing Record 36 of Set 11 | islampur
# Processing Record 37 of Set 11 | baghdad
# Processing Record 38 of Set 11 | monywa
# Processing Record 39 of Set 11 | rio gallegos
# Processing Record 40 of Set 11 | vitim
# Processing Record 41 of Set 11 | yerbogachen
# Processing Record 42 of Set 11 | limoux
# Processing Record 43 of Set 11 | nanortalik
# Processing Record 44 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 11 | napasar
# Processing Record 46 of Set 11 | hasaki
# Processing Record 47 of Set 11 | bandiagara
# Processing Record 48 of Set 11 | bonthe
# Processing Record 49 of Set 11 | angoram
# Processing Record 50 of Set 11 | dong hoi
# Processing Record 1 of Set 12 | batagay-alyta
# Processing Record 2 of Set 12 | murindo
# Processing Record 3 of Set 12 | meridian
# Processing Record 4 of Set 12 | mildura
# Processing Record 5 of Set 12 | sa kaeo
# Processing Record 6 of Set 12 | morondava
# Processing Record 7 of Set 12 | dawson
# Processing Record 8 of Set 12 | lamesa
# Processing Record 9 of Set 12 | martin
# Processing Record 10 of Set 12 | lexington
# Processing Record 11 of Set 12 | mafeteng
# Processing Record 12 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 12 | caravelas
# Processing Record 14 of Set 12 | camacha
# Processing Record 15 of Set 12 | benguela
# Processing Record 16 of Set 12 | mitoc
# Processing Record 17 of Set 12 | samana
# Processing Record 18 of Set 12 | igarka
# Processing Record 19 of Set 12 | talara
# Processing Record 20 of Set 12 | vilyuysk
# Processing Record 21 of Set 12 | inuvik
# Processing Record 22 of Set 12 | port blair
# Processing Record 23 of Set 12 | omsukchan
# Processing Record 24 of Set 12 | davila
# Processing Record 25 of Set 12 | dhidhdhoo
# Processing Record 26 of Set 12 | tyukalinsk
# Processing Record 27 of Set 12 | cartagena
# Processing Record 28 of Set 12 | ljungby
# Processing Record 29 of Set 12 | jinchang
# Processing Record 30 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 12 | bowen
# Processing Record 32 of Set 12 | norsup
# Processing Record 33 of Set 12 | naifaru
# Processing Record 34 of Set 12 | qaqortoq
# Processing Record 35 of Set 12 | kalmunai
# Processing Record 36 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 37 of Set 12 | kahului
# Processing Record 38 of Set 12 | morant bay
# Processing Record 39 of Set 12 | oranjestad
# Processing Record 40 of Set 12 | opuwo
# Processing Record 41 of Set 12 | sao jose da coroa grande
# Processing Record 42 of Set 12 | yermekeyevo
# Processing Record 43 of Set 12 | jardim
# Processing Record 44 of Set 12 | uk
# City not found. Skipping...
# Processing Record 45 of Set 12 | sovetskiy
# Processing Record 46 of Set 12 | tougan
# Processing Record 47 of Set 12 | bairnsdale
# Processing Record 48 of Set 12 | ust-tsilma
# Processing Record 49 of Set 12 | muskogee
# Processing Record 50 of Set 12 | aguimes
# Processing Record 1 of Set 13 | rogers
# Processing Record 2 of Set 13 | umm lajj
# Processing Record 3 of Set 13 | imbituba
# Processing Record 4 of Set 13 | la solana
# Processing Record 5 of Set 13 | ewa beach
# Processing Record 6 of Set 13 | paro
# Processing Record 7 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 8 of Set 13 | mpigi
# Processing Record 9 of Set 13 | lilongwe
# Processing Record 10 of Set 13 | wilmington
# Processing Record 11 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 12 of Set 13 | horodnya
# Processing Record 13 of Set 13 | chilca
# Processing Record 14 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 13 | richards bay
# Processing Record 16 of Set 13 | arman
# Processing Record 17 of Set 13 | ucluelet
# Processing Record 18 of Set 13 | curillo
# Processing Record 19 of Set 13 | beira
# Processing Record 20 of Set 13 | ati
# Processing Record 21 of Set 13 | buala
# Processing Record 22 of Set 13 | bathsheba
# Processing Record 23 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 13 | koungheul
# Processing Record 25 of Set 13 | nicoya
# Processing Record 26 of Set 13 | menongue
# Processing Record 27 of Set 13 | abu samrah
# Processing Record 28 of Set 13 | bure
# Processing Record 29 of Set 13 | shingu
# Processing Record 30 of Set 13 | aykhal
# Processing Record 31 of Set 13 | portland
# Processing Record 32 of Set 13 | nizhniy kuranakh
# Processing Record 33 of Set 13 | quatre cocos
# Processing Record 34 of Set 13 | nelson bay
# Processing Record 35 of Set 13 | shahr-e kord
# Processing Record 36 of Set 13 | tongren
# Processing Record 37 of Set 13 | ahuimanu
# Processing Record 38 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 13 | erzin
# Processing Record 40 of Set 13 | chateaudun
# Processing Record 41 of Set 13 | dunedin
# Processing Record 42 of Set 13 | kishtwar
# Processing Record 43 of Set 13 | khuzdar
# Processing Record 44 of Set 13 | virovitica
# Processing Record 45 of Set 13 | tura
# Processing Record 46 of Set 13 | margate
# Processing Record 47 of Set 13 | madimba
# Processing Record 48 of Set 13 | rome
# Processing Record 49 of Set 13 | le moule
# Processing Record 50 of Set 13 | garwa
# Processing Record 1 of Set 14 | kandi
# Processing Record 2 of Set 14 | ayan
# Processing Record 3 of Set 14 | nishihara
# Processing Record 4 of Set 14 | moroni
# Processing Record 5 of Set 14 | brest
# Processing Record 6 of Set 14 | katherine
# Processing Record 7 of Set 14 | bhainsdehi
# Processing Record 8 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 14 | mirnyy
# Processing Record 10 of Set 14 | buseresere
# Processing Record 11 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 14 | silver city
# Processing Record 13 of Set 14 | mogadishu
# Processing Record 14 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 15 of Set 14 | mangaratiba
# Processing Record 16 of Set 14 | abakaliki
# Processing Record 17 of Set 14 | batemans bay
# Processing Record 18 of Set 14 | pangnirtung
# Processing Record 19 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 14 | san policarpo
# Processing Record 21 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 14 | berdigestyakh
# Processing Record 23 of Set 14 | ndele
# Processing Record 24 of Set 14 | bogorodskoye
# Processing Record 25 of Set 14 | linxia
# Processing Record 26 of Set 14 | chhatarpur
# Processing Record 27 of Set 14 | gao
# Processing Record 28 of Set 14 | koshurnikovo
# Processing Record 29 of Set 14 | tall kayf
# Processing Record 30 of Set 14 | luganville
# Processing Record 31 of Set 14 | nyurba
# Processing Record 32 of Set 14 | melfi
# Processing Record 33 of Set 14 | namibe
# Processing Record 34 of Set 14 | cortez
# Processing Record 35 of Set 14 | guanica
# Processing Record 36 of Set 14 | urumqi
# Processing Record 37 of Set 14 | riosucio
# Processing Record 38 of Set 14 | gallup
# Processing Record 39 of Set 14 | ortigueira
# Processing Record 40 of Set 14 | zhigansk
# Processing Record 41 of Set 14 | nouadhibou
# Processing Record 42 of Set 14 | salinas
# Processing Record 43 of Set 14 | synya
# Processing Record 44 of Set 14 | saint-joseph
# Processing Record 45 of Set 14 | majene
# Processing Record 46 of Set 14 | san juan
# Processing Record 47 of Set 14 | dorchester
# Processing Record 48 of Set 14 | bandarbeyla
# Processing Record 49 of Set 14 | longkou
# Processing Record 50 of Set 14 | bungu
# Processing Record 1 of Set 15 | kharp
# Processing Record 2 of Set 15 | beirut
# Processing Record 3 of Set 15 | zhangjiakou
# Processing Record 4 of Set 15 | manaus
# Processing Record 5 of Set 15 | ulaangom
# Processing Record 6 of Set 15 | cabra
# Processing Record 7 of Set 15 | maykain
# City not found. Skipping...
# Processing Record 8 of Set 15 | belmonte
# Processing Record 9 of Set 15 | helmbrechts
# Processing Record 10 of Set 15 | shaunavon
# Processing Record 11 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 12 of Set 15 | alibag
# Processing Record 13 of Set 15 | ulmu
# Processing Record 14 of Set 15 | warri
# Processing Record 15 of Set 15 | santiago del estero
# Processing Record 16 of Set 15 | cap malheureux
# Processing Record 17 of Set 15 | chester
# Processing Record 18 of Set 15 | svetlyy
# Processing Record 19 of Set 15 | achisay
# City not found. Skipping...
# Processing Record 20 of Set 15 | bontang
# Processing Record 21 of Set 15 | darnah
# Processing Record 22 of Set 15 | atambua
# Processing Record 23 of Set 15 | kathu
# Processing Record 24 of Set 15 | tolaga bay
# Processing Record 25 of Set 15 | diego de almagro
# Processing Record 26 of Set 15 | raudeberg
# Processing Record 27 of Set 15 | guerrero negro
# Processing Record 28 of Set 15 | taksimo
# Processing Record 29 of Set 15 | pyaozerskiy
# Processing Record 30 of Set 15 | rawson
# Processing Record 31 of Set 15 | kayerkan
# Processing Record 32 of Set 15 | carevo
# City not found. Skipping...
# Processing Record 33 of Set 15 | antofagasta
# Processing Record 34 of Set 15 | uyskoye
# Processing Record 35 of Set 15 | bonfim
# Processing Record 36 of Set 15 | xining
# Processing Record 37 of Set 15 | coreau
# Processing Record 38 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 15 | kimbe
# Processing Record 40 of Set 15 | yadgir
# Processing Record 41 of Set 15 | houston
# Processing Record 42 of Set 15 | the valley
# Processing Record 43 of Set 15 | acari
# Processing Record 44 of Set 15 | tuy hoa
# Processing Record 45 of Set 15 | aripuana
# Processing Record 46 of Set 15 | virginia beach
# Processing Record 47 of Set 15 | espanola
# Processing Record 48 of Set 15 | asekeyevo
# Processing Record 49 of Set 15 | schruns
# Processing Record 50 of Set 15 | krasnyy chikoy
# Processing Record 1 of Set 16 | conde
# Processing Record 2 of Set 16 | yeppoon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                  Pisco      PE -13.7000  -76.2167     62.02        82
# 1               Westport      US  41.1415  -73.3579     55.26        84
# 2              Hithadhoo      MV  -0.6000   73.0833     82.96        70
# 3                  Rocha      UY -34.4833  -54.3333     63.03        76
# 4              Cape Town      ZA -33.9258   18.4232     61.12        87
# 5           Ponta Do Sol      PT  32.6667  -17.1000     68.72        66
# 6                Ushuaia      AR -54.8000  -68.3000     46.06        53
# 7               Khandyga      RU  62.6667  135.6000     30.43        86
# 8                Kavieng      PG  -2.5744  150.7967     85.50        68
# 9  San Vicente De Canete      PE -13.0751  -76.3835     63.88        84
#
#    Cloudiness  Wind Speed Current Description
# 0           0       13.80           clear sky
# 1          90        3.00     overcast clouds
# 2          73       13.33       broken clouds
# 3           0        5.91           clear sky
# 4          20        1.01          few clouds
# 5          25        4.21    scattered clouds
# 6           0        0.00           clear sky
# 7         100        9.15     overcast clouds
# 8          31        7.99    scattered clouds
# 9          15        4.52          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
